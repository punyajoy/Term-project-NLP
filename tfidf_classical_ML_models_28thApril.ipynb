# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split,StratifiedKFold

from sklearn.svm import LinearSVC,SVC
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier, RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import classification_report,confusion_matrix
from imblearn.over_sampling import RandomOverSampler,SMOTE
import numpy as np

n_folds = 10
def imb_prepare(X, y):
    #  For SVM
    #sm = SMOTE(kind='svm', random_state=4991)
    # For non-SVM
    #sm = SMOTE(random_state=4991)
    oversample = RandomOverSampler()
    # fit and apply the transform
    X_over, y_over = oversample.fit_resample(X, y)
    #X_resampled, y_resampled = sm.fit_sample(X, y)
    return X_over, y_over



total_data_eng = pd.read_csv("Total_data_annotated_eng_clean_28thApril.csv")
X = np.array(total_data_eng['translated'])
y = np.array(total_data_eng['label'])

# This is for the train-test split
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4991)
#print("Training set size : ", len(X_train), " ; Test set size : ", len(X_test))

max_feat_list = [500, 1000, 2000, 5000, 10000, 25000]

for max_feat_elem in max_feat_list:
    ngram_vectorizer = TfidfVectorizer(min_df=0.0025, max_df=0.25,ngram_range=(1,3), max_features=max_feat_elem, stop_words='english')
    kf = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=2020)

    acc_whl = []
    precision_whl = []
    recall_whl = []
    f1_whl = []
    print("-------------------------------------------------------------------")
    print("For max_features value : ", max_feat_elem)
    print("-------------------------------------------------------------------")

    for train, test in kf.split(X, y):
        clf = LogisticRegression()
        #clf = LinearSVC(random_state=4991)
        #clf = RandomForestClassifier(random_state=4991)
        #clf = AdaBoostClassifier(random_state=4991)
        #clf = GradientBoostingClassifier(random_state=4991)
        #clf = GaussianNB()
        clf = SVC(kernel="rbf", random_state=4991)
        trainX = X[train]
        trainY = y[train]
        testX = X[test]
        testY = y[test]
    
        tfidf_train = ngram_vectorizer.fit_transform(trainX).A
        tfidf_test = ngram_vectorizer.transform(testX).A
        #print("Training data shape : ", tfidf_train.shape, " ; Test data shape : ", tfidf_test.shape)

        tfidf_train = np.array(tfidf_train)
        tfidf_test = np.array(tfidf_test)
        y_train = np.array(trainY)
        y_test = np.array(testY)

        tfidf_train, y_train = imb_prepare(tfidf_train, y_train)
        clf.fit(tfidf_train, y_train)
        y_pred = clf.predict(tfidf_test)
        #print("Predicted : ", y_pred)
        #print("True labels : ", y_test)
        
        #print(classification_report(y_test, y_pred))

        tn, fp, fn, tp = confusion_matrix(testY, y_pred).ravel()
        accuracy = (tp+tn)*1.0/(tn+fp+fn+tp)
        precision = (tp*1.0)/(tp+fp)
        recall = (tp*1.0)/(tp+fn)
        f1_score = (2.0*precision*recall)/(precision+recall)
        acc_whl.append(accuracy)
        precision_whl.append(precision)
        recall_whl.append(recall)
        f1_whl.append(f1_score)

    print("Overall accuracy : ", sum(acc_whl) / n_folds)
    print("Overall precision : ", sum(precision_whl) / n_folds)
    print("Overall recall : ", sum(recall_whl) / n_folds)
    print("Overall f1-score : ", sum(f1_whl)/ n_folds)

# %%
total_data_eng = pd.read_csv("Total_data_annotated_eng_clean_28thApril.csv")

# %%
total_data_eng
# Out:
#           id  label                                         translated  \
# 0     207102      0  *   Jammu Kashmir: Encounter continues   in Bu...
# 1     135627      0  * It is a sign of maturity and deep understand...
# 2     665173      0  The Indian Army carried out this operation in ...
# 3     543553      0  A new drama has become popular in the name of ...
# 4     231428      0  *   Know what we all do not have to do at such...
# 5     609443      0  .60000 people will stand in saf from the Kaaba...
# 6     576275      0  Ghulam Nabi Azad did not just say that Ajit Do...
# 7     499523      0         3      Why did Muhammad Marry Several W...
# 8     664274      0  Shaktahin Mughal was the nominal ruler of Delh...
# 9     715422      0  Doubt is getting deeper! In most of the cities...
# 10    141866      1  * Wayanad's true history and Rahul Gandhi * * ...
# 11    665183      0  The Indian Army carried out this operation in ...
# 12    119318      1  The time has come     to consider it. I have t...
# 13    734780      0  In the service, All India Muslim Shebe Baraat ...
# 14     12582      0  #Dalal_Media_Moradabad:   Today 15 soldiers we...
# 15    603133      1  The date was May 1, 2006, when the morning new...
# 16     77519      1  * Akhand Sanatan Samiti   * It is famous about...
# 17     83426      0  * Internal supporters of terrorism * Sometimes...
# 18    738575      1  The name of the attacker is Azad Mohammed ... ...
# 19    666576      0  Mangal Pandey was hanged,   Tantya Tope was   ...
# 20    956195      0   *Islam Gymkhana organised First  Dawaat-E-Ift...
# 21    669194      1  Mamta Banerjee's real name is ... Mumtaz Masam...
# 22    110268      0  * Wardwise list of successful Muslim candidate...
# 23    153183      1  * Lessons for Hindus * Very few people probabl...
# 24    145923      0  * Video of suspect in Sri Lankan bomb   blasts...
# 25    163285      1  * Beehives swarming with Hindus in the guise o...
# 26    954584      0     I am delighted with all of you, keep this n...
# 27     54522      0  * Momta Banarjee stands with Pakistan * * Afte...
# 28    952262      0  *     So everyone will   speak with one voice ...
# 29    503875      1  If someone is your neighbor .. If you are a ne...
# ..       ...    ...                                                ...
# 394  1418232      0  *   Sushma said in OIC meeting   - fight again...
# 395  1476928      1  # Nathuram_Godsay Please share so that informa...
# 396   257514      1  Jihad is behind terror and jihad is followed b...
# 397  1338351      1  *Another day, another mosque down in China*.  ...
# 398   525831      0  Karin-e-Zindagi 24 *     * *        *] *    * ...
# 399   751901      1  Rathore Veer Amar Singh was in a high position...
# 400   438130      0  Come, let me introduce you to the duplicity of...
# 401   514421      0  *      News Good   morning * * 21 February, 20...
# 402   153240      1  Except Chating, definitely read this post or e...
# 403   501760      0  Majlis       5 Matabua                 Urdu Ac...
# 404   368515      0   Acharya Dr. Vijay Shankar Mishra (Administrat...
# 405  1033934      1  *Wayanad*  It's a district with a little over ...
# 406  1431944      0  *     * FIR lodged   in Amhubani for violation...
# 407  1068659      1  *This is what happens when you become a minori...
# 408   777130      0  MIND BLOWING NEHRU BIOGRAPHY  For those who be...
# 409  1340537      1  Chinese Police shoots dead 3 Uyghur Muslim you...
# 410  1279035      0  Secular Sri Lanka bathed in blood .. Christian...
# 411  1321459      1   * Jai Bhim Namo Budhay *  * Jai Constitution ...
# 412   874039      0  The full video of his interview is in this lin...
# 413   506167      0  G. Adab. Nalegaon Ta. Chakur District Latur, t...
# 414   209069      1  The ideology of ISIS, a terrorist organization...
# 415   545341      0  Bhim Army founder Chandrashekhar Azad said 'Re...
# 416  1488315      0  *Islamic State Claims Responsibility for Sri L...
# 417  1416998      1  The biggest surprise of the Kali Yuga is that ...
# 418  1488273      0  *Islamic State Claims Responsibility for Sri L...
# 419   186922      0  * Listen Hindus! * Citizenship Amendment Bill ...
# 420   770211      0  Now the time has come to look at some recent s...
# 421   426729      1  There are 6 types of Quran in the world. All t...
# 422   140627      0  India's first Muslim Prime Minister to be form...
# 423  1667507      1  Watch the video carefully.  Muslims are taking...
#
#      eng_len
# 0       1143
# 1       3886
# 2       1523
# 3       3864
# 4       4159
# 5       1299
# 6       2127
# 7       2430
# 8       5296
# 9       3218
# 10      1061
# 11      1523
# 12      5492
# 13       591
# 14      1117
# 15      1881
# 16      2298
# 17      3272
# 18      2516
# 19      3197
# 20       557
# 21      2495
# 22      1166
# 23      3177
# 24      1723
# 25      2691
# 26       586
# 27       966
# 28      4654
# 29      1982
# ..       ...
# 394     1277
# 395     5296
# 396     2691
# 397      281
# 398     1489
# 399     3390
# 400     2054
# 401     4041
# 402     2936
# 403     5203
# 404     5513
# 405      612
# 406     1887
# 407      279
# 408     3509
# 409      386
# 410     3536
# 411     1670
# 412      148
# 413     1478
# 414     1456
# 415      223
# 416      887
# 417      539
# 418      900
# 419     1444
# 420     3829
# 421     1715
# 422     2092
# 423      296
#
# [424 rows x 4 columns]

# %%
def mapping_to_actual_data(dataframe_clustered,dataframe_actual,label_to_transfer):
    #dataframe_actual[label_to_transfer]=np.zeros((len(dataframe_actual)),dtype=int)
    list_df=[]
    for index,row in tqdm(dataframe_clustered.iterrows(),total=len(dataframe_clustered)):
        for ele in row['repeated messages']:
            #dataframe_actual.iloc[ele][label_to_transfer]=row[label_to_transfer]
            list_df.append((ele,row[label_to_transfer]))
            
    list_df.sort(key=lambda tup: tup[0])
    print(list_df[0:5])
    list_temp=[ele[1] for ele in list_df]
    dataframe_actual[label_to_transfer]=list_temp
    return dataframe_actual

# %%
total_data_to_annnotate['pred_label']=list(np.ones((len(total_data_to_annnotate)),dtype=int))

# %%
total_data_to_annnotate.head(5)
# Out:
#    repeated messages                                    three annotator  \
# id
# 1           [216814]  [319b41df-41e6-40e9-a0b4-5cc1b5baf290, d736cba...
# 2           [945024]  [c7b9d20e-2c35-4b9c-b380-7cf8cb5f822d, 394490c...
# 3           [275899]  [cb49c64f-aec9-4d19-91a5-0168058d6cea, 910caaa...
# 4           [112639]  [5411f849-2c32-4bf9-9c0c-b2369963d34f, 0131ef1...
# 5           [141987]  [8a398de0-b259-49ab-9932-0d5aee2ccc6a, d2281b6...
#
#                                                  text  keywords_count  \
# id
# 1                          వీరశైవ లింగాయత్ లను మరి...               0
# 2                    ఆహ్వానము పెదనందిపాడు జిల్లా ప...               0
# 3                 ముఖ్య గమనిక  జనసేన పార్టీ అభ్యర్...               0
# 4                ( Updated on 01 - 12 - 2018) നമസ്...               0
# 5                ( Updated on 14 - 12 - 2018) നമസ്...               0
#
#                                            translated  pred_label
# id
# 1   Chandrababu Forgetting Veera Siva Lingayats! C...           1
# 2   NTR Sports Development Center (Indoor Stadium)...           1
# 3   IMPORTANT NOTE: The candidates for the Janasen...           1
# 4   (Updated on 01 - 12 - 2018) Namaste, Janmabhoo...           1
# 5                                                 NaN           1

# %%
temp=mapping_to_actual_data(total_data_to_annnotate,actual_data,'pred_label')
# Out:
# 100%|██████████| 975989/975989 [01:13<00:00, 13196.54it/s]
# [(0, 1), (1, 1), (2, 1), (3, 1), (4, 1)]

# %%
temp.head(5)
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# 0           0             0               0               4.0
# 1           1             1               1               9.0
# 2           2             2               2              10.0
# 3           3             3               3              11.0
# 4           4             4               4              13.0
#
#    Unnamed: 0.1.1.1.1  group_id_anonymized lang  \
# 0                 4.0                  577   hi
# 1                 9.0                 2037   hi
# 2                10.0                 3634   hi
# 3                11.0                 2284   hi
# 4                13.0                 3700   te
#
#                                         message_text  phone_num_anonymized  \
# 0  *लघु सिंचाई*  निःशुल्क बोरिंग योजना हेतु 55 कर...                178320
# 1  *📰FR62* *👉दिल्ली-एनसीआर में शिमला जैसी बर्फबार...                 39877
# 2  कल मैने एक आदमी से लिफ्ट माँगा उसके बाद धन्यवा...                198635
# 3  कल मैने एक आदमी से लिफ्ट माँगा उसके बाद धन्यवा...                198635
# 4  సర్వేలు సూసి మురిసి పోవద్దు మిత్రులు బాబు జిత్...                153553
#
#        timestamp                                         translated  \
# 0  1549559608000  * Provision of Rs. 55 crore for minor irrigati...
# 1  1549559738000  * 📰  📰FR62 👉  * * Shimla-like snowfall in Delh...
# 2  1549559843000  Yesterday I asked for a lift from a man, after...
# 3  1549559851000  Yesterday I asked for a lift from a man, after...
# 4  1549559896000                   Surveys Don't Surprise Friends
#
#    pred_label
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
